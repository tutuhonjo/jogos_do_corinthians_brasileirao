# %%
# Bibliotecas utilizadas
import pandas as pd
import time
from selenium import webdriver
from datetime import date
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By


# Inicializador do WebDriver
servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
# Declarando variáveis
jogos = []
datas = []
horas = []
locais = []

# %%
# Try/Finnaly para garantir a saída do WebDriver no fim do código
try:
    # Abrindo na página do brasileirão serie A
    navegador.get('https://ge.globo.com/futebol/brasileirao-serie-a/')
    navegador.maximize_window()
    
    #For para quantidade de rodadas no Brasileirão
    for i in range(38):
        #Localizar jogos da rodada
        tabela_jogos = navegador.find_elements(By.CLASS_NAME, 'lista-jogos__jogo')
        for jogo in tabela_jogos:
            #Condição para buscar jogos do corinthians na rodada
            if "COR" in jogo.text: 
                #Armazenando número da rodada na variável "rodada"
                rodada = navegador.find_element(By.CLASS_NAME, 'lista-jogos__navegacao--rodada')

                #Armazenando informações do jogo na variábel "info"
                info = jogo.find_element(By.CLASS_NAME, 'jogo__informacoes')

                #Isolando em uma variável o local do jogo, armazenando na variável "info"
                local = info.find_element(By.CLASS_NAME, 'jogo__informacoes--local')

                #Isolando em uma variável a data do jogo, armazenando na variável "info"
                data = info.find_element(By.CLASS_NAME, 'jogo__informacoes--data')

                #Isolando em uma variável o hora do jogo, armazenando na variável "info"
                hora = info.find_element(By.CLASS_NAME, 'jogo__informacoes--hora')

                #Armazenando o placar na variável "placar"
                placar = jogo.find_element(By.CLASS_NAME, 'placar')

                #Printando os jogos encontrados
                print(f'DATA - {data.text} \nLocal - {local.text} \nHora - {hora.text}\n\nJOGO\n{placar.text}\n\n')

                #Armazenando valores em uma lista
                jogos.append(placar.text)
                datas.append(data.text)
                horas.append(hora.text)
                locais.append(local.text)

        #Clicando em próxima rodada para seguir o WebScraping        
        navegador.find_element(By.XPATH, '//*[@id="classificacao__wrapper"]/section/nav/span[3]').click()
        time.sleep(0.5)

finally:
    # Fecha o navegador após o uso
    navegador.quit()
# Out:
# DATA - 25/07
# Local - Neo Química Arena
# Hora - 20:00
#
# JOGO
# COR
# 2
# 2
# GRE
#
#
# DATA - 28/07
# Local - Arena MRV
# Hora - 19:00
#
# JOGO
# CAM
# 2
# 1
# COR
#
#
# DATA - 04/08
# Local - Neo Química Arena
# Hora - 16:00
#
# JOGO
# COR
# 1
# 1
# JUV
#
#
# DATA - 10/08
# Local - Neo Química Arena
# Hora - 21:30
#
# JOGO
# COR
# 1
# 1
# RBB
#
#
# DATA - 17/08
# Local - Maracanã
# Hora - 21:00
#
# JOGO
# FLU
# 0
# 0
# COR
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 13
#      10 tabela_jogos = navegador.find_elements(By.CLASS_NAME, 'lista-jogos__jogo')
#      11 for jogo in tabela_jogos:
#      12     #Condição para buscar jogos do corinthians na rodada
# ---> 13     if "COR" in jogo.text:
#      14         #Armazenando número da rodada na variável "rodada"
#      15         rodada = navegador.find_element(By.CLASS_NAME, 'lista-jogos__navegacao--rodada')
#      17         #Armazenando informações do jogo na variábel "info"
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\selenium\webdriver\remote\webdriver.py:352, in WebDriver.execute(self, driver_command, params)
#     349     elif "sessionId" not in params:
#     350         params["sessionId"] = self.session_id
# --> 352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
#     354     self.error_handler.check_response(response)
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:306, in RemoteConnection.execute(self, command, params)
#     304 trimmed = self._trim_large_entries(params)
#     305 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 306 return self._request(command_info[0], url, body=data)
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:326, in RemoteConnection._request(self, method, url, body)
#     323     body = None
#     325 if self.keep_alive:
# --> 326     response = self._conn.request(method, url, body=body, headers=headers)
#     327     statuscode = response.status
#     328 else:
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\urllib3\_request_methods.py:136, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     133     urlopen_kw["body"] = body
#     135 if method in self._encode_url_methods:
# --> 136     return self.request_encode_url(
#     137         method,
#     138         url,
#     139         fields=fields,  # type: ignore[arg-type]
#     140         headers=headers,
#     141         **urlopen_kw,
#     142     )
#     143 else:
#     144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\urllib3\_request_methods.py:183, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     180 if fields:
#     181     url += "?" + urlencode(fields)
# --> 183 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Arthur\Desktop\github\jogos_do_corinthians_brasileirao\corinthians\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Transformando listas do WebScraping em Dataframe
df = pd.DataFrame({'Data': datas, 'Hora': horas, 'Local':locais, 'Jogo':jogos})

#Código para inserir data atual no Excel
mask = '%d%m%Y'
hoje = date.today().strftime(mask)

#Extraindo Dataframe em Excel
df.to_excel(f'jogos do corinthians {hoje}.xlsx', index=False)
